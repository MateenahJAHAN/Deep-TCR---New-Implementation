# %% [markdown]
# # Day 4: Understand Data 📊
#
# ## 🎯 Today's Goal
#
# Calculate statistics, visualize data, and compare responders vs non-responders!
#
# **Time:** 2-3 hours
# **Difficulty:** ⭐⭐ Easy-Medium
#
# **From LEARNING_ROADMAP.md - Week 1 Exercises:**
# - Load 5 different patient files
# - Calculate average repertoire size
# - Find most common V genes across all patients
# - Plot sequence length distributions
#
# ---
#
# ## 📚 What You'll Learn Today
#
# - How to load multiple patient files
# - How to calculate statistics across patients
# - How to create visualizations (plots)
# - How to compare responders vs non-responders
#
# ---
#
# ## 🤔 Questions to Think About
#
# 1. **How do I load multiple files?**
#    - Hint: Use a loop (for loop)
#    - Hint: Use `glob` or `os.listdir()` to find files
#
# 2. **What is "repertoire size"?**
#    - Number of unique sequences per patient
#    - Think: How many different T cell barcodes?
#
# 3. **How do I make plots?**
#    - Use matplotlib: `import matplotlib.pyplot as plt`
#    - Use seaborn for prettier plots: `import seaborn as sns`

# %% [markdown]
# ## Step 1: Load Multiple Patient Files
#
# **From Roadmap:** Load 5 different patient files
#
# **Your Task:** Load multiple patient files and see how many sequences each has

# %%
import pandas as pd
from pathlib import Path

# Find data directory
data_dir = Path("../data/DeepTCR_Cancer-master/Data/yost/data")

# TODO: List all TSV files
# Hint: Use .glob("*.tsv")
# Write your code here:


# TODO: Select 5 files (you can pick any 5)
# Write your code here:


# TODO: Load each file and count sequences
# Hint: Use a for loop
# For each file:
#   1. Load it with pd.read_csv(file, sep='\t')
#   2. Filter to productive sequences
#   3. Count how many sequences
#   4. Store the result
# Write your code here:

# %% [markdown]
# ## Step 2: Calculate Average Repertoire Size
#
# **From Roadmap:** Calculate average repertoire size
#
# **Your Task:** Calculate the average number of sequences across all patients

# %%
# TODO: Calculate average repertoire size
# Hint: If you have a list of counts, use sum() / len()
# Or use numpy: np.mean(list)
# Write your code here:


# TODO: Also calculate min, max, median
# Write your code here:

# %% [markdown]
# ## Step 3: Find Most Common V Genes Across All Patients
#
# **From Roadmap:** Find most common V genes across all patients
#
# **Your Task:** Combine V gene data from all patients and find which V genes are most common

# %%
# TODO: Collect V genes from all patients
# Hint: Loop through patients, get vGeneName column, combine them
# Write your code here:


# TODO: Count how many times each V gene appears
# Hint: Use .value_counts()
# Write your code here:


# TODO: Show top 10 most common V genes
# Hint: Use .head(10)
# Write your code here:

# %% [markdown]
# ## Step 4: Plot Sequence Length Distributions
#
# **From Roadmap:** Plot sequence length distributions
#
# **Your Task:** Create a histogram showing sequence length distribution

# %%
import matplotlib.pyplot as plt
import numpy as np

# TODO: Collect sequence lengths from one patient (or all patients)
# Hint: df['aminoAcid'].str.len()
# Write your code here:


# TODO: Create a histogram
# Hint: plt.hist(lengths, bins=20)
# Hint: plt.xlabel('Sequence Length')
# Hint: plt.ylabel('Count')
# Hint: plt.title('Sequence Length Distribution')
# Hint: plt.show()
# Write your code here:

# %% [markdown]
# ## Step 5: Load Response Labels
#
# **Your Task:** Load the response.csv file to see which patients responded

# %%
# TODO: Load response labels
# File is at: ../data/DeepTCR_Cancer-master/Data/yost/response.csv
# Write your code here:


# TODO: Print the response data
# Write your code here:


# TODO: Count how many responders vs non-responders
# Hint: Look at the response column and count values
# Write your code here:

# %% [markdown]
# ## Step 6: Compare Responders vs Non-Responders
#
# **Your Task:** Compare statistics between responders and non-responders

# %%
# TODO: For each patient, get their repertoire size and response
# Hint: Loop through patients, load file, count sequences, get response
# Write your code here:


# TODO: Separate responders and non-responders
# Hint: Filter based on response column
# Write your code here:


# TODO: Calculate average repertoire size for each group
# Write your code here:


# TODO: Create a comparison plot (bar chart or box plot)
# Hint: Use seaborn: sns.boxplot() or sns.barplot()
# Write your code here:

# %% [markdown]
# ## ✅ Summary: What You Learned Today
#
# **From LEARNING_ROADMAP.md - Week 1 completed!**
#
# ✅ Loaded multiple patient files
# ✅ Calculated average repertoire size
# ✅ Found most common V genes
# ✅ Plotted sequence length distributions
# ✅ Compared responders vs non-responders
#
# **Pandas operations:**
# - Loading multiple files
# - Combining data from multiple files
# - Calculating statistics
# - Filtering and grouping
#
# **Visualization:**
# - Creating histograms
# - Creating comparison plots
#
# ## 🎉 You're Done with Day 4!
#
# **Next Step:** Go to `Day_05_Encode_Sequences/Day_05_Encode_Sequences.ipynb`
#
# **This completes Week 1 from the roadmap!** 🎊
