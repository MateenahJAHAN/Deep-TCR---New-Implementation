# %% [markdown]
# # Day 8: Understand Multiple Instance Learning 🎓
#
# ## 🎯 Today's Goal
#
# Understand why TCR-seq prediction needs Multiple Instance Learning (MIL)!
#
# **Time:** 2-3 hours
# **Difficulty:** ⭐⭐ Easy-Medium (conceptual)
#
# **From LEARNING_ROADMAP.md - Week 3:**
# - Understand bag of sequences concept
# - Understand why simple averaging isn't enough
# - Understand need for attention/weighting
# - Repertoire-level vs sequence-level
#
# ---
#
# ## Step 1: Compare Traditional ML vs MIL
#
# **Your Task:** Understand the difference

# %%
# Traditional ML (what you know)
# TODO: Create example
# X = 3 samples, 2 features each
# y = 3 labels (one per sample)
# Write your code here:


# TCR-seq MIL (what's new)
# TODO: Create example
# X = 50,000 sequences (one patient)
# y = 1 label (for entire patient)
# Write your code here:


print("Traditional ML:")
print(f"  X shape: {X_traditional.shape}")
print(f"  y shape: {y_traditional.shape}")
print(f"  Each row has a label: ✓")

print("\nTCR-seq MIL:")
print(f"  X shape: {X_mil.shape}")
print(f"  y shape: {y_mil.shape}")
print(f"  Entire matrix has ONE label: ⚠️")

# %% [markdown]
# ## Step 2: Why Can't We Use Normal ML?
#
# **Your Task:** Think about why we can't train on individual sequences

# %% [markdown]
# **Questions to answer (write your thoughts):**
#
# 1. Why can't we just train a classifier on individual sequences?
#    - Answer: ________________________________
#
# 2. What is the "bag of sequences" concept?
#    - Answer: ________________________________
#
# 3. Why does simple averaging (mean pooling) lose information?
#    - Answer: ________________________________

# %% [markdown]
# ## Step 3: Understand Attention Mechanism
#
# **Your Task:** Understand what attention does conceptually

# %%
# Conceptually, attention does this:
# TODO: Implement simple attention example
# 1. Sequences: (num_sequences, features)
# 2. Calculate importance scores for each sequence
# 3. Weighted average based on importance

def simple_attention_pooling(sequences, importance_scores):
    """
    Simple attention pooling (conceptual)
    """
    # TODO: Normalize importance scores (make them sum to 1)
    # Write your code here:
    
    
    # TODO: Calculate weighted average
    # Hint: sequences * weights, then sum
    # Write your code here:
    
    
    return weighted_avg

# TODO: Test with example
# Write your code here:

# %% [markdown]
# ## ✅ Summary
#
# ✅ Understood MIL concept
# ✅ Understood why normal ML doesn't work
# ✅ Understood need for attention
#
# **Key insight:** The model LEARNS which sequences are important!
#
# **Next Step:** Go to `Day_09_DeepTCR_Setup/Day_09_DeepTCR_Setup.ipynb`
