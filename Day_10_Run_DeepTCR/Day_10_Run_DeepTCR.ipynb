# %% [markdown]
# # Day 10: Run DeepTCR 🚀
#
# ## 🎯 Today's Goal
#
# Train the actual DeepTCR model and make predictions!
#
# **Time:** 3 hours
# **Difficulty:** ⭐⭐⭐ Medium
#
# **From LEARNING_ROADMAP.md - Week 5 & 6:**
# - Train model on Yost data
# - Make predictions
# - Evaluate AUC (target ~0.82)
# - Extract attention weights
#
# ---
#
# ## Step 1: Initialize Model
#
# **Your Task:** Create a DeepTCR model instance

# %%
from DeepTCR.DeepTCR import DeepTCR_SS

# TODO: Initialize model
# model = DeepTCR_SS('my_model_name')
# Write your code here:

# %% [markdown]
# ## Step 2: Load Data
#
# **Your Task:** Load data in DeepTCR format

# %%
# TODO: Load data
# model.Get_Data(
#     directory='data/DeepTCR_Cancer-master/Data/yost/',
#     Load_Prev_Data=False,
#     classes=[0, 1]  # Non-responder, Responder
# )
# Write your code here:

# %% [markdown]
# ## Step 3: Train Model
#
# **Your Task:** Train the model

# %%
# TODO: Train model
# model.Train_Supervised_Repertoire(
#     batch_size=10,
#     epochs=100
# )
# Write your code here:

# %% [markdown]
# ## Step 4: Make Predictions
#
# **Your Task:** Predict on test data

# %%
# TODO: Make predictions
# predictions = model.Predict_Repertoire()
# Write your code here:

# %% [markdown]
# ## Step 5: Evaluate Results
#
# **From Roadmap:** Evaluate AUC (should get ~0.82)
#
# **Your Task:** Calculate AUC and other metrics

# %%
from sklearn.metrics import roc_auc_score, accuracy_score

# TODO: Calculate AUC
# Write your code here:


# TODO: Calculate accuracy
# Write your code here:


print(f"AUC: {auc:.3f}")
print(f"Accuracy: {accuracy:.3f}")

# %% [markdown]
# ## Step 6: Extract Attention Weights
#
# **From Roadmap:** Extract attention weights
#
# **Your Task:** Get attention weights to see which sequences matter

# %%
# TODO: Get attention weights
# attention = model.Get_Attention_Weights()
# Write your code here:


# TODO: Analyze top sequences
# Write your code here:

# %% [markdown]
# ## ✅ Summary: What You Learned Today
#
# **From LEARNING_ROADMAP.md - Week 5 & 6 completed!**
#
# ✅ Trained DeepTCR model
# ✅ Made predictions
# ✅ Evaluated results (AUC)
# ✅ Extracted attention weights
#
# **Congratulations! You've replicated the paper! 🎉**
#
# ## 🎊 You're Done!
#
# You've completed the entire learning journey from pandas to DeepTCR!
#
# **What you accomplished:**
# - Learned TCR-seq data structure
# - Cleaned and preprocessed data
# - Encoded sequences for ML
# - Understood Multiple Instance Learning
# - Trained DeepTCR model
# - Reproduced paper results!
