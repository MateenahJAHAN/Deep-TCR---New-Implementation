# %% [markdown]
# # Day 7: Simple ML Baselines 🤖
#
# ## 🎯 Today's Goal
#
# Try simple machine learning approaches before understanding MIL!
#
# **Time:** 3 hours
# **Difficulty:** ⭐⭐⭐ Medium
#
# **From LEARNING_ROADMAP.md - Week 3:**
# - Implement mean pooling baseline
# - Try max pooling baseline
# - Compare to random prediction
# - Use sklearn with simple aggregation
#
# ---
#
# ## Step 1: Mean Pooling Baseline
#
# **Your Task:** Average all sequences for each patient

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# TODO: Implement mean pooling
# For each patient:
#   - Take all sequences (shape: num_sequences, features)
#   - Calculate mean along sequence axis
#   - Result: (features,) - one vector per patient
def mean_pooling(sequences):
    # TODO: Write your code here
    pass

# TODO: Apply to all patients
# Write your code here:

# %% [markdown]
# ## Step 2: Train Simple Classifier
#
# **Your Task:** Use sklearn to train a classifier on mean-pooled features

# %%
# TODO: Prepare data
# X = mean-pooled features (num_patients, features)
# y = labels (num_patients,)
# Write your code here:


# TODO: Split data
# Write your code here:


# TODO: Train classifier
# Write your code here:


# TODO: Evaluate
# Write your code here:

# %% [markdown]
# ## Step 3: Try Max Pooling
#
# **Your Task:** Implement max pooling (take strongest sequence)

# %%
# TODO: Implement max pooling
# Similar to mean, but use .max() instead of .mean()
# Write your code here:

# %% [markdown]
# ## ✅ Summary
#
# ✅ Implemented mean pooling
# ✅ Implemented max pooling
# ✅ Trained sklearn baseline
# ✅ Understood why simple pooling might not work well
#
# **Next Step:** Go to `Day_08_Understand_MIL/Day_08_Understand_MIL.ipynb`
