# %% [markdown]
# # Day 9: DeepTCR Setup 📦
#
# ## 🎯 Today's Goal
#
# Install and set up the DeepTCR package!
#
# **Time:** 2 hours
# **Difficulty:** ⭐⭐ Easy-Medium
#
# **From LEARNING_ROADMAP.md - Week 5:**
# - Install DeepTCR package
# - Understand DeepTCR API
# - Load data in DeepTCR format
#
# ---
#
# ## Step 1: Install DeepTCR
#
# **Your Task:** Install the package

# %%
# TODO: Install DeepTCR
# In Jupyter: !pip install DeepTCR
# In terminal: pip install DeepTCR
# Write your code here:

# !pip install DeepTCR

# %% [markdown]
# ## Step 2: Import DeepTCR
#
# **Your Task:** Import and verify installation

# %%
# TODO: Import DeepTCR
# from DeepTCR.DeepTCR import DeepTCR_SS
# Write your code here:


# TODO: Print version or verify import worked
# Write your code here:

# %% [markdown]
# ## Step 3: Understand DeepTCR Data Format
#
# **Your Task:** Learn what format DeepTCR expects

# %%
# TODO: Check DeepTCR documentation
# DeepTCR expects:
# - Directory with patient folders
# - Each folder has TCR files
# - Response labels file

# TODO: Explore the data directory structure
# Write your code here:

# %% [markdown]
# ## ✅ Summary
#
# ✅ Installed DeepTCR
# ✅ Understood DeepTCR API
# ✅ Prepared data format
#
# **Next Step:** Go to `Day_10_Run_DeepTCR/Day_10_Run_DeepTCR.ipynb`
