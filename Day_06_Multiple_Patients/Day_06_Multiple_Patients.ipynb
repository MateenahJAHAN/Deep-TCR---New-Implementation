# %% [markdown]
# # Day 6: Multiple Patients 👥
#
# ## 🎯 Today's Goal
#
# Work with multiple patients and create patient batches!
#
# **Time:** 2-3 hours
# **Difficulty:** ⭐⭐ Easy-Medium
#
# **From LEARNING_ROADMAP.md - Week 2:**
# - Create a batch of 5 patients' data
# - Combine features from multiple patients
#
# ---
#
# ## 📚 What You'll Learn Today
#
# - How to load multiple patient files
# - How to process each patient
# - How to create batches of patient data
# - How to handle different repertoire sizes

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# TODO: Load all patient files
# Hint: Use glob to find all TSV files
# Write your code here:


# TODO: Process each patient
# For each file:
#   1. Load the file
#   2. Filter to productive sequences
#   3. Clean the data
#   4. Store patient data
# Write your code here:

# %% [markdown]
# ## Step 2: Create Patient Batches
#
# **From Roadmap:** Create a batch of 5 patients' data
#
# **Your Task:** Combine encoded data from multiple patients

# %%
# TODO: Encode sequences for each patient
# Use your encoding function from Day 5
# Write your code here:


# TODO: Create a batch
# Hint: Use np.array() or list of arrays
# Note: Patients have different numbers of sequences!
# Write your code here:

# %% [markdown]
# ## ✅ Summary
#
# ✅ Loaded multiple patients
# ✅ Created patient batches
#
# **Next Step:** Go to `Day_07_Simple_ML/Day_07_Simple_ML.ipynb`
