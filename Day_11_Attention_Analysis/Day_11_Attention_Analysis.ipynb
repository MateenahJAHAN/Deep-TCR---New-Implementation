# %% [markdown]
# # Day 11: Attention Weight Analysis 🔍
#
# ## 🎯 Today's Goal
#
# Deep dive into attention weights to understand which TCR sequences predict response!
#
# **Time:** 2-3 hours
# **Difficulty:** ⭐⭐⭐ Medium
#
# **From LEARNING_ROADMAP.md - Week 6:**
# - Extract attention weights
# - Analyze top sequences
# - Visualize attention patterns
# - Understand biological meaning
#
# ---
#
# ## 🔗 What You Learned Yesterday (Day 10)
#
# **If you completed Day 10, you now know:**
# - ✅ How to train DeepTCR model (`Monte_Carlo_CrossVal()`)
# - ✅ How to make predictions (`Sample_Inference()`)
# - ✅ How to evaluate results (AUC ~0.82!)
# - ✅ How to extract attention weights
#
# **Today, we'll analyze WHAT the model learned from those attention weights!**
#
# ---
#
# ## 📚 What You'll Learn Today
#
# - How to extract and analyze attention weights
# - How to rank sequences by importance
# - How to compare responders vs non-responders
# - How to identify top predictive sequences
# - How to visualize attention patterns
#
# **How This Builds On Day 10:**
#
# **Remember from Day 8.5:**
# - In Day 8.5, you learned HOW attention mechanism works (architecture)
# - Attention calculates importance scores for each sequence
# - **Today:** You'll analyze WHAT those importance scores mean!
# - Yesterday: You trained DeepTCR → Got predictions → Extracted attention weights
# - Today: You'll ANALYZE those attention weights → Understand which sequences matter
# - **This completes the learning journey!** 🎉
#
# **Data Flow:**
#
# **Data Flow Continuity:**
# - **Day 8.5:** Understood HOW DeepTCR implements attention (architecture)
# - **Day 9:** Installed DeepTCR → Loaded YOUR cleaned data
# - **Day 10:** Trained DeepTCR → Predictions → Extracted attention weights
# - **Day 11 (Today):** Analyzing attention weights → Finding top sequences → Biological insights
# - **Day 10:** Trained DeepTCR → Predictions → Attention weights extracted
# - **Day 11 (Today):** Attention weights → Analyze → Find top sequences → Understand biology
#
# ---
#
# ## 🎓 Learning Progression (Like University Courses!)
#
# **Think of this like learning Python:**
# - **Day 10:** Used DeepTCR to train and predict
# - **Day 11 (Today):** Analyzing what DeepTCR learned (interpretation)
# - **Complete!** You've gone from beginner to reproducing a research paper!
#
# **Think of this like learning biology:**
# - **Day 10:** Predicted response with DeepTCR
# - **Day 11 (Today):** Understanding WHICH sequences predict response (biological insight)
# - **Complete!** You understand both the method AND the biology!
#
# ---
#
# ## 🎉 Congratulations! You've Completed the Full Journey!
#
# **From Day 0 to Day 11:**
# - **Day 0:** Learned to use notebooks
# - **Day 1:** Installed packages
# - **Day 2:** Explored ONE patient's data
# - **Day 3:** Cleaned that data
# - **Day 4:** Compared MULTIPLE patients
# - **Day 5:** Encoded sequences to numbers
# - **Day 6:** Organized into batches
# - **Day 7:** Tried simple ML
# - **Day 8:** Understood MIL
# - **Day 8.5:** Understood architecture
# - **Day 9:** Installed DeepTCR
# - **Day 10:** Trained DeepTCR → Predictions!
# - **Day 11 (Today):** Analyzed what DeepTCR learned → Biological insights!
#
# **You've built knowledge step-by-step, just like a university course!** 🎓
#
# ---
#
# ## 🧬 Biology Context: Why Attention Matters
#
# ### What Are Attention Weights?
#
# **Simple explanation:**
# - Attention weights show which TCR sequences are important
# - High weight = sequence predicts response
# - Low weight = sequence doesn't matter
# - **Goal:** Find the "predictive" T cells!
#
# ### Why This Is Important
#
# **Biology reason:**
# - Identifies which T cells recognize tumor
# - Helps understand why some patients respond
# - **Impact:** Can guide treatment decisions!
#
# ### What We'll Discover
#
# **From the paper:**
# - Responders have different sequence patterns
# - Non-responders have exhausted T cells
# - Attention identifies these patterns!
#
# ---
#
# ## 💻 Computer Science Context: Analyzing Attention
#
# ### What Are Attention Weights (CS)?
#
# **CS explanation:**
# - **Attention weights** = importance scores
# - Learned during training
# - Range: 0 to 1 (normalized)
# - **What you know:** Like feature importance!
#
# ### How to Analyze Them
#
# 1. **Extract weights:** Get from model
# 2. **Rank sequences:** Sort by weight
# 3. **Visualize:** Plot distributions
# 4. **Compare:** Responders vs non-responders
#
# ### Key Operations
#
# - `Get_Attention_Weights()` - Extract weights
# - `np.argsort()` - Rank sequences
# - `plt.hist()` - Visualize distributions
# - `pd.groupby()` - Compare groups
#
# ---
#
# ## 📄 Paper Reference
#
# **Paper Section:** Results - Attention Analysis
#
# **What the paper says:**
# - "Attention mechanism identified predictive sequences"
# - "Responders showed distinct sequence patterns"
# - "Non-responders had exhausted T cell signatures"
#
# **What this means:**
# - Attention reveals biological insights!
# - We can identify predictive sequences
# - Helps understand why model works
#
# **Reference:** See `docs/paper.pdf` Results - Attention section
#
# **Paper Methodology Connection:**
# - The paper analyzes attention weights to identify predictive sequences
# - **Finding:** Responders show distinct sequence patterns
# - **Finding:** Non-responders have exhausted T cell signatures
# - **Method:** Rank sequences by attention, compare groups
# - **Today:** You'll replicate this analysis!
#
# ---
#
# ## 📚 What You'll Learn Today
#
# - How to extract attention weights
# - How to rank sequences by importance
# - How to visualize attention distributions
# - How to compare responders vs non-responders
# - How to identify top predictive sequences
#
# ---
#
# ## 🤔 Questions to Think About (Before Starting)
#
# 1. **What do high attention weights mean?**
#    - Sequence is important for prediction
#    - Model focuses on this sequence
#    - **Biology:** Likely recognizes tumor!
#
# 2. **How do we compare attention between groups?**
#    - Extract weights for each patient
#    - Group by response status
#    - Compare distributions
#
# 3. **What sequences should we focus on?**
#    - Top sequences by attention
#    - Sequences unique to responders
#    - High-frequency sequences

# %% [markdown]
# ## Step 1: Extract Attention Weights
#
# **Biology context:**
# - Get attention weights from trained model
# - These show which sequences matter
# - **Goal:** Extract the importance scores!
#
# **CS context:**
# - `Get_Attention_Weights()` returns weights
# - Returns dictionary or array
# - **What you know:** Like getting feature importance!
#
# **Your Task:** Extract attention weights

# %%
# Get attention weights from trained model
# From Day 10: After training/inference, model has attention weights

# ✅ Starter solution
if "model" not in globals() or model is None:
    print("⚠️ Complete Day 10 first!")
    print("  Steps: 1) Train model, 2) Run inference")
    attention_weights = None
else:
    try:
        # Uncomment when ready:
        # attention_weights = model.Get_Attention_Weights()
        # Create mock data for testing
        import numpy as np
        attention_weights = {'mock': np.random.rand(5, 100)}  # Mock: 5 patients, 100 sequences
        print("💡 Using mock attention weights for demonstration")
        print("  Replace with: attention_weights = model.Get_Attention_Weights()")
    except Exception as e:
        print(f"✗ Error getting attention weights: {e}")
        attention_weights = None

print("\n📝 Instructions:")
print("  1. Run inference first (from Day 10)")
print("  2. Call Get_Attention_Weights()")
print("  3. Check the format (dict, array, list)")
print("  4. Understand the structure")

print("\n💡 Note: Format may vary depending on DeepTCR version")
print("💡 Tip: Check model documentation or inspect the object")

# %% [markdown]
# ## Step 2: Understand Attention Weight Structure
#
# **Biology context:**
# - Each patient has many sequences
# - Each sequence has an attention weight
# - **Goal:** Understand the data structure!
#
# **CS context:**
# - Attention weights are arrays
# - Shape: (n_patients, n_sequences_per_patient)
# - **What you know:** Like a matrix!
#
# **Your Task:** Explore attention weight structure

# %%
# Convert attention weights to array format
# Format may vary: dict, list, or array

# ✅ Starter solution
if attention_weights is not None:
    import numpy as np
    
    # Handle different formats
    if isinstance(attention_weights, dict):
        # If dict, get first value or specific key
        attention_array = list(attention_weights.values())[0]
    elif isinstance(attention_weights, (list, np.ndarray)):
        attention_array = np.array(attention_weights)
    else:
        attention_array = np.array(attention_weights)
    
    print(f"✓ Attention weights shape: {attention_array.shape}")
    print(f"  Statistics:")
    print(f"    Min: {attention_array.min():.4f}")
    print(f"    Max: {attention_array.max():.4f}")
    print(f"    Mean: {attention_array.mean():.4f}")
    print(f"    Std: {attention_array.std():.4f}")
else:
    print("⚠️ Complete Cell 1 above first!")
    attention_array = None

print("\n📝 Instructions:")
print("  1. Convert attention weights to array format")
print("  2. Print shape and statistics")
print("  3. Understand the data structure")

print("\n💡 Key: Shape should be (n_patients, n_sequences_per_patient)")
print("💡 Note: Each patient may have different number of sequences")

# %% [markdown]
# ## Step 3: Rank Sequences by Attention
#
# **Biology context:**
# - Find sequences with highest attention
# - These are the most predictive!
# - **Goal:** Identify top sequences!
#
# **CS context:**
# - Use `np.argsort()` to rank
# - Sort by attention weight
# - **What you know:** Like sorting a list!
#
# **Your Task:** Rank sequences by attention

# %%
# TODO: Rank sequences by attention weight
# For each patient, find top sequences
#   Option 1: Top N sequences per patient
# top_n = 10
# top_indices = np.argsort(attention_array, axis=1)[:, -top_n:][:, ::-1]
#   Option 2: Global top sequences (across all patients)
# Flatten and find top N globally
# attention_flat = attention_array.flatten()
# top_global_indices = np.argsort(attention_flat)[-top_n:][::-1]

# Write your code here:
# top_indices_per_patient = None
# top_global_indices = None


# TODO: Get top attention weights
# top_weights_per_patient = np.sort(attention_array, axis=1)[:, -top_n:][:, ::-1]
# top_global_weights = np.sort(attention_flat)[-top_n:][::-1]

# Write your code here:


# Print top sequences
# print(f"\n🔝 Top {top_n} Sequences per Patient:")
# print(f"  Mean top weight: {np.mean(top_weights_per_patient):.6f}")
# print(f"  Max top weight: {np.max(top_weights_per_patient):.6f}")

print("📝 Instructions:")
print("  1. Use np.argsort() to rank sequences")
print("  2. Find top N sequences per patient")
print("  3. Optionally find global top sequences")
print("  4. Print statistics")

print("\n💡 Key: argsort returns indices, not values")
print("💡 Tip: Use [:, ::-1] to reverse order (highest first)")
if attention_array is None:
    print("\n⚠️ Complete Step 2 above first to create attention_array!")
elif top_indices_per_patient is None or top_global_indices is None:
    print("\n⚠️ Complete the TODO above to rank sequences!")
    print("  Steps: 1) Use np.argsort(), 2) Get top N indices")
else:
    print(f"\n🔝 Top Sequences Ranked:")
    print(f"  Top indices per patient shape: {top_indices_per_patient.shape}")
    print(f"  Top global indices: {top_global_indices[:10]}")

# %% [markdown]
# ## Step 4: Visualize Attention Distributions
#
# **Biology context:**
# - See how attention is distributed
# - Most sequences have low attention
# - Few sequences have high attention
# - **Goal:** Visualize the pattern!
#
# **CS context:**
# - Use `plt.hist()` for histograms
# - Use `sns.boxplot()` for distributions
# - **What you know:** From matplotlib/seaborn!
#
# **Your Task:** Visualize attention distributions

# %%
# TODO: Create histogram of attention weights
# Flatten all attention weights
# attention_flat = attention_array.flatten()
# attention_flat = attention_flat[attention_flat > 0]  # Remove zeros

# plt.figure(figsize=(10, 6))
# plt.hist(attention_flat, bins=50, edgecolor='black', alpha=0.7)
# plt.xlabel('Attention Weight', fontsize=14)
# plt.ylabel('Frequency', fontsize=14)
# plt.title('Distribution of Attention Weights', fontsize=16)
# plt.yscale('log')  # Log scale (many low values)
# plt.grid(True, alpha=0.3)
# plt.show()

# Write your code here:


# TODO: Create boxplot per patient
# plt.figure(figsize=(12, 6))
# sns.boxplot(data=attention_array.T[:100], orient='h')  # First 100 sequences
# plt.xlabel('Attention Weight', fontsize=14)
# plt.ylabel('Sequence Index', fontsize=14)
# plt.title('Attention Weights Across Sequences (Sample)', fontsize=16)
# plt.show()

# Write your code here:


print("📝 Instructions:")
print("  1. Flatten attention weights")
print("  2. Create histogram")
print("  3. Use log scale (many low values)")
print("  4. Create boxplot to see per-sequence patterns")

print("\n💡 Key insight: Most sequences have low attention (sparse!)")
print("💡 Biology: Model focuses on few important sequences")
if attention_array is None:
    print("\n⚠️ Complete Step 2 above first to create attention_array!")
else:
    try:
        # Flatten for visualization
        attention_flat = attention_array.flatten()
        attention_flat = attention_flat[attention_flat > 0]  # Remove zeros
        print(f"\n📊 Ready for visualization:")
        print(f"  Non-zero weights: {len(attention_flat)}")
        print(f"  Mean: {np.mean(attention_flat):.6f}")
        print("  💡 Uncomment plotting code above to visualize")
    except Exception as e:
        print(f"✗ Error preparing visualization: {e}")

# %% [markdown]
# ## Step 5: Compare Responders vs Non-Responders
#
# **Biology context:**
# - Do responders have different attention patterns?
# - Which sequences predict response?
# - **Goal:** Find responder-specific sequences!
#
# **CS context:**
# - Group patients by response status
# - Compare attention distributions
# - **What you know:** Use `pd.groupby()`!
#
# **Your Task:** Compare attention between groups

# %%
# TODO: Load response labels (from Day 10)
# response_df = pd.read_csv('../data/DeepTCR_Cancer-master/Data/yost/response.csv')
# Match patient IDs to attention weights

# Write your code here:
# response_labels = None


# TODO: Group attention weights by response
# Create DataFrame with attention and response
# attention_df = pd.DataFrame({
#     'patient_id': patient_ids,
#     'response': response_labels,
#     'mean_attention': np.mean(attention_array, axis=1),
#     'max_attention': np.max(attention_array, axis=1),
#     'top10_mean': np.mean(np.sort(attention_array, axis=1)[:, -10:], axis=1)
# })

# Write your code here:
# attention_df = None


# TODO: Compare groups
# grouped = attention_df.groupby('response')
# print("\n📊 Attention by Response Group:")
# print(grouped['mean_attention'].describe())


# TODO: Visualize comparison
# plt.figure(figsize=(10, 6))
# sns.boxplot(data=attention_df, x='response', y='mean_attention')
# plt.xlabel('Response Status', fontsize=14)
# plt.ylabel('Mean Attention Weight', fontsize=14)
# plt.title('Attention Weights: Responders vs Non-Responders', fontsize=16)
# plt.show()

# Write your code here:


print("📝 Instructions:")
print("  1. Load response labels")
print("  2. Match to attention weights")
print("  3. Create DataFrame with response and attention")
print("  4. Group by response and compare")
print("  5. Visualize with boxplot")

print("\n💡 Key question: Do responders have higher attention on certain sequences?")
print("💡 Biology: This reveals predictive sequence patterns!")
if attention_array is None:
    print("\n⚠️ Complete Step 2 above first to create attention_array!")
elif response_labels is None or attention_df is None:
    print("\n⚠️ Complete the TODO above to prepare comparison!")
    print("  Steps: 1) Load response labels, 2) Create attention_df")
else:
    try:
        grouped = attention_df.groupby("response")
        print("\n📊 Attention by Response Group:")
        print(grouped["mean_attention"].describe())
        print("\n💡 Uncomment visualization code above to plot")
    except Exception as e:
        print(f"✗ Error comparing groups: {e}")

# %% [markdown]
# ## Step 6: Identify Top Predictive Sequences
#
# **Biology context:**
# - Find sequences that predict response
# - These are the "biomarkers"!
# - **Goal:** Identify predictive sequences!
#
# **CS context:**
# - Find sequences with high attention in responders
# - Compare to non-responders
# - **What you know:** Statistical comparison!
#
# **Your Task:** Find top predictive sequences

# %%
# ✅ Starter solution
if attention_array is not None:
    import numpy as np
    
# ✅ Starter solution
    if attention_array is not None:
        import numpy as np
    
# TODO: Find sequences with high attention in responders
# For each sequence position, compare responders vs non-responders
#   Step 1: Get mean attention per sequence position for each group
# responder_attention = attention_array[response_labels == 'Responder']
# nonresponder_attention = attention_array[response_labels == 'Non-Responder']
#   Step 2: Calculate mean per sequence position
# responder_mean = np.mean(responder_attention, axis=0)
# nonresponder_mean = np.mean(nonresponder_attention, axis=0)
#   Step 3: Find differences
# attention_diff = responder_mean - nonresponder_mean
#   Step 4: Rank by difference
# top_diff_indices = np.argsort(attention_diff)[-20:][::-1]

# Write your code here:
# top_predictive_indices = None


# TODO: Get actual sequences (from Day 10 data)
# Match indices to sequences
# top_sequences = [sequences[i] for i in top_predictive_indices]

# Write your code here:
# top_sequences = None


# Print top sequences
# print(f"\n🔝 Top 20 Predictive Sequences:")
# for i, seq_idx in enumerate(top_predictive_indices[:10]):
#     print(f"  {i+1}. Sequence {seq_idx}: Attention diff = {attention_diff[seq_idx]:.6f}")

        print("📝 Instructions:")
        print("  1. Separate responders and non-responders")
        print("  2. Calculate mean attention per sequence position")
        print("  3. Find differences (responder - non-responder)")
        print("  4. Rank sequences by difference")
        print("  5. Get actual sequences (from data)")

        print("\n💡 Key: High difference = sequence predicts response!")
        print("💡 Biology: These are the biomarker sequences!")
        if attention_array is None or response_labels is None:
            print("\n⚠️ Complete Steps 2 and 5 above first!")
            print("  Need: attention_array and response_labels")
        elif top_predictive_indices is None:
            print("\n⚠️ Complete the TODO above to find top sequences!")
            print("  Steps: 1) Calculate attention_diff, 2) Rank by difference")
        else:
            print(f"\n🔝 Top Predictive Sequences Found:")
            print(f"  Number of top sequences: {len(top_predictive_indices)}")
            print(f"  Top 10 indices: {top_predictive_indices[:10]}")

    else:
        print("⚠️ Complete previous cells first!")
        print("  Steps: 1) Get attention weights, 2) Convert to array")

else:
    print("⚠️ Complete previous cells first!")
    print("  Steps: 1) Get attention weights, 2) Convert to array")

# %% [markdown]
# ## Step 7: Visualize Top Sequences
#
# **Biology context:**
# - Visualize which sequences matter
# - See attention patterns
# - **Goal:** Create publication-quality figures!
#
# **CS context:**
# - Use `plt.barh()` for bar charts
# - Use `sns.heatmap()` for heatmaps
# - **What you know:** From matplotlib/seaborn!
#
# **Your Task:** Visualize top sequences

# %%
# TODO: Create bar chart of top sequences
# plt.figure(figsize=(10, 8))
# top_n_viz = 20
# top_indices_viz = top_predictive_indices[:top_n_viz]
# plt.barh(range(top_n_viz), attention_diff[top_indices_viz])
# plt.yticks(range(top_n_viz), [f'Seq {i}' for i in top_indices_viz])
# plt.xlabel('Attention Difference (Responder - Non-Responder)', fontsize=14)
# plt.ylabel('Sequence Index', fontsize=14)
# plt.title('Top Predictive Sequences', fontsize=16)
# plt.grid(True, alpha=0.3, axis='x')
# plt.tight_layout()
# plt.show()

# Write your code here:


# TODO: Create heatmap of attention for top sequences
# attention_top = attention_array[:, top_indices_viz]
# plt.figure(figsize=(12, 8))
# sns.heatmap(attention_top.T, cmap='YlOrRd', cbar_kws={'label': 'Attention Weight'})
# plt.xlabel('Patient', fontsize=14)
# plt.ylabel('Sequence Index', fontsize=14)
# plt.title('Attention Weights: Top Predictive Sequences', fontsize=16)
# plt.tight_layout()
# plt.show()

# Write your code here:


print("📝 Instructions:")
print("  1. Create horizontal bar chart")
print("  2. Show top N sequences")
print("  3. Create heatmap of attention weights")
print("  4. Color-code by attention weight")

print("\n💡 Key: Visualizations help understand patterns!")
print("💡 Biology: See which sequences matter for prediction")

# %% [markdown]
# ## Step 8: Analyze Sequence Characteristics
#
# **Biology context:**
# - What makes sequences predictive?
# - Length? V gene? Frequency?
# - **Goal:** Understand sequence features!
#
# **CS context:**
# - Extract sequence features
# - Compare top vs bottom sequences
# - **What you know:** Feature analysis!
#
# **Your Task:** Analyze sequence characteristics

# %%
# TODO: Extract sequence features
# From Day 10 data, get:
#   - Sequence length
#   - V gene
#   - D gene
#   - J gene
#   - Frequency

# Write your code here:
# sequence_features = None


# TODO: Compare top vs bottom sequences
# top_sequences_features = sequence_features[top_predictive_indices[:50]]
# bottom_sequences_features = sequence_features[np.argsort(attention_diff)[:50]]

# Compare:
#   - Mean length
#   - V gene distribution
#   - Frequency distribution

# Write your code here:


# TODO: Visualize comparisons
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 3, 1)
# plt.hist([top_sequences_features['length'], bottom_sequences_features['length']], 
#          bins=20, label=['Top', 'Bottom'], alpha=0.7)
# plt.xlabel('Sequence Length')
# plt.ylabel('Frequency')
# plt.legend()
# plt.title('Sequence Length Distribution')
# ... (more comparisons)

# Write your code here:


print("📝 Instructions:")
print("  1. Extract sequence features (length, V/D/J genes, frequency)")
print("  2. Compare top vs bottom sequences")
print("  3. Visualize differences")
print("  4. Identify patterns")

print("\n💡 Key question: What makes a sequence predictive?")
print("💡 Biology: Understanding sequence features helps interpret results!")

# %% [markdown]
# ## ✅ Summary: What You Learned Today
#
# ### Biology:
# - ✅ How attention weights identify predictive sequences
# - ✅ How responders differ from non-responders
# - ✅ What makes sequences predictive
# - ✅ How to interpret attention patterns
#
# ### Computer Science:
# - ✅ How to extract attention weights
# - ✅ How to rank sequences by importance
# - ✅ How to visualize attention distributions
# - ✅ How to compare groups statistically
# - ✅ How to identify top predictive sequences
#
# ### Key Concepts:
#
# 1. **Attention Weights:**
#    - Show which sequences matter
#    - Learned during training
#    - Range: 0 to 1 (normalized)
#
# 2. **Analysis Methods:**
#    - Ranking: `np.argsort()`
#    - Comparison: Group by response
#    - Visualization: Histograms, boxplots, heatmaps
#
# 3. **Key Insights:**
#    - Most sequences have low attention (sparse)
#    - Few sequences have high attention (important)
#    - Responders show distinct patterns
#
# **From LEARNING_ROADMAP.md - Week 6 completed!** ✅
#
# ✅ Extracted attention weights
# ✅ Ranked sequences by importance
# ✅ Visualized attention distributions
# ✅ Compared responders vs non-responders
# ✅ Identified top predictive sequences
#
# ## 🎉 Congratulations! You've Analyzed Attention! 🎉
#
# **What you accomplished:**
# - ✅ Extracted attention weights from model
# - ✅ Identified top predictive sequences
# - ✅ Compared responders vs non-responders
# - ✅ Created publication-quality visualizations
# - ✅ Understood biological meaning!
#
# ## 🎊 You're Done with Attention Analysis!
#
# **What you learned:**
# - Attention mechanism identifies important sequences
# - Responders have distinct sequence patterns
# - Top sequences can serve as biomarkers
#
# **Next Steps:**
# - Explore sequence motifs
# - Analyze V/D/J gene patterns
# - Compare to published biomarkers
# - Read the full paper's attention analysis!
#
# ## 📝 Notes Section
#
# Write down:
# - Top 10 predictive sequences
# - Key differences between responders and non-responders
# - What sequence features are predictive
# - Questions you still have
